# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://quotes.toscrape.com"
current_url = "/"

data_list = []

while current_url:
    response = requests.get(url + current_url)
    soup = BeautifulSoup(response.text,'html.parser')

    quote = soup.find_all(class_="quote")
    for q in quote:
        message = q.find("span",class_="text")
        author = q.find("small",class_="author")
        
        data_list.append({"Quote":message.text,"Author":author.text})
     
    next_button = soup.find('li',class_='next')
    
    if next_button:
        current_url  = next_button.find('a')['href']
        print("path: ",current_url)
    else:
        current_url = None

df = pd.DataFrame(data_list)
df.to_csv("quotes_data.xlsx", index=False)

# print(data_list)

# j = 1
# for i in data_list:
#     print(f"{j}:{i}")
#     j += 1
# Out:
# path:  /page/2/
# path:  /page/3/
# path:  /page/4/
# path:  /page/5/
# path:  /page/6/
# path:  /page/7/
# path:  /page/8/
# path:  /page/9/
# path:  /page/10/
