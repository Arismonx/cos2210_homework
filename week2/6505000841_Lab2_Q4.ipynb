# %% [markdown]
# ## Q4
# จงเขียนโปรแกรมที่รับจำนวนนักเรียนที่เข้าสอบ (เป็นจำนวนบวกเท่านั้น) แล้ววนรับคะแนนของนักเรียนที่เข้าสอบให้ครบและหา
# - คะแนนเฉลี่ยของนักเรียนทั้งหมด
# - คะแนนเฉลี่ยของนักเรียนที่สอบผ่าน (ได้คะแนนอย่างน้อย 5)
# - คะแนนเฉลี่ยของนักเรียนที่สอบไม่ผ่าน (ได้คะแนนต่ำกว่า 5)
# - คะแนนสูงสุดของนักเรียนทั้งหมด

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **3** <br>
# Student 1 : **10** <br>
# Student 2 : **6.5** <br>
# Student 3 : **0** <br>
# Average score : 5.5 <br>
# Average passing score : 8.25 <br>
# Average failing score : 0.0 <br>
# Highest score : 10.0 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **5** <br>
# Student 1 : **10** <br>
# Student 2 : **6.5** <br>
# Student 3 : **0** <br>
# Student 4 : **9** <br>
# Student 5 : **8.25** <br>
# Average score : 6.75 <br>
# Average passing score : 8.4375<br>
# Average failing score : 0.0 <br>
# Highest score : 10.0

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **7** <br>
# Student 1 : **9** <br>
# Student 2 : **6.5** <br>
# Student 3 : **0** <br>
# Student 4 : **10** <br>
# Student 5 : **8.25** <br>
# Student 6 : **9.50** <br>
# Student 7 : **7.25** <br>
# Average score : 7.214285714285714 <br>
# Average passing score : 8.416666666666666 <br>
# Average failing score : 0.0 <br>
# Highest score : 10.0 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **-1** <br>
# Incorrect Input. Number of students : **7** <br>
# Student 1 : **10** <br>
# Student 2 : **6.5** <br>
# Student 3 : **0** <br>
# Student 4 : **9** <br>
# Student 5 : **8.25** <br>
# Student 6 : **9.50** <br>
# Student 7 : **7.25** <br>
# Average score : 7.214285714285714 <br>
# Average passing score : 8.416666666666666 <br>
# Average failing score : 0.0 <br>
# Highest score : 10.0 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **3** <br>
# Student 1 : **6** <br>
# Student 2 : **5.5** <br>
# Student 3 : **9.8** <br>
# Average score : 7.1000000000000005 <br>
# Average passing score : 7.1000000000000005 <br>
# Average failing score : No student failed <br>
# Highest score : 9.8 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Number of students : **3** <br>
# Student 1 : **1** <br>
# Student 2 : **2.5** <br>
# Student 3 : **3.5** <br>
# Average score : 2.3333333333333335 <br>
# Average passing score : No student passed <br>
# Average failing score : 2.3333333333333335 <br>
# Highest score : 3.5 <br>

# %%
number = input("Number of students:")

while int(number) <= 0:
    number = input("Incorrect Input.Number of students:")

number = int(number)

total = 0.0
avg_all = 0
s_pass = 0
s_fail = 0
heigh_score = 0.0

for i in range(number):
    score = input(f"Studen {i+1} :")
    
    score = float(score)
    
    if score > 5:
        s_pass += 1
    else:
        s_fail += 1
    
    if score > heigh_score:
        heigh_score = score
    
    print(f"Studen {i+1} : {score}")
    total += score

print(f"Average score : {total/number}")

if s_pass == 0 :
    print("Average passing score : No student passed")
else:
    print(f"Average passing score : {total/s_pass}")
    
if s_fail == 0 :
    print("Average failing score : No student failing")
else:
    print(f"Average failing score  : {total/s_fail}")

print(f"Highest score : {heigh_score}")
# Out:
# Studen 1 : 10.0
# Studen 2 : 6.5
# Studen 3 : 0.0
# Studen 4 : 9.0
# Studen 5 : 8.25
# Studen 6 : 9.5
# Studen 7 : 7.25
# Average score : 7.214285714285714
# Average passing score : 8.416666666666666
# Average failing score  : 50.5
# Highest score : 10.0
