# %% [markdown]
# ---
# ## Q2
# จงเขียนโปรแกรมที่รับชื่อและนามสกุลจากผู้ใช้ แล้วนำมาสร้างเป็นสตริงใหม่ 2 สตริง โดย
#
# - สตริงหนึ่งเป็นชื่อต่อด้วยนามสกุลและมีช่องว่าง (blank) คั่นกลาง
#
# - อีกสตริงหนึ่งเป็นนามสกุลต่อด้วยชื่อและมี , ต่อด้วยช่องว่างคั่นกลาง
#
# แล้วแสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Firstname Lastname: Somsak Saksri <br>
# Hello! Somsak Saksri<br>
# Saksri, Somsak

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Firstname Lastname: Jackson Wang <br>
# Hello! Jackson Wang <br>
# Wang, Jackson <br>

# %%
first_name , last_name = input("Enter first name and last name:").split()
full_name_1 = first_name +" "+last_name
full_name_2 = first_name +","+last_name

print(f"Firstname Lastname:{first_name} {last_name}")
print(f"Hello! {full_name_1}")
print(full_name_2)
# Out:
# Firstname Lastname:Samart Sanomnao
# Hello! Samart Sanomnao
# Samart,Sanomnao
