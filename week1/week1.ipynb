# %%
number = input("Enter your number")

# %%
number = 5

# %% [markdown]
# เปลี่ยนเป็น type int

# %%
print(type(number))
print(number)
# Out:
# <class 'str'>
# 6

# %%
print("Hello","cos2210",sep=", ",end=' ')
print("COMSCI RU")
# Out:
# Hello, cos2210 COMSCI RU

# %% [markdown]
# - sep = '',',' คือตัวคั้นกลาง
# - end = '\n',' ' จบด้วย
