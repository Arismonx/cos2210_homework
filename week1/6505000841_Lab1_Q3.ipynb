# %% [markdown]
# ---
# ## Q3
# จงเขียนโปรแกรมที่รับชื่อและอายุจากผู้ใช้ แล้วคำนวณปีเกิดของผู้ใช้และแสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการรัน:
#
# Name, age: Somsak 19 <br>
# Somsak's year of birth is 2549.

# %% [markdown]
# ##### ตัวอย่างการรัน:
#
# Name, age: Bella 2 <br>
# Bella's year of birth is 2566.

# %%
name , age = input("Enter name and age:").split(",")
cal_age = 2568 - int(age)
print(f"Name,age:{name} {age}")
print(f"{name}'s year of birthis {cal_age}.")
# Out:
# Name,age:Samart 22
# Samart's year of birthis 2546.
