# %% [markdown]
# ---
# ## Q4
# จงเขียนโปรแกรมที่รับชื่อและอายุจากผู้ใช้ แล้วคำนวณปีเกิดของผู้ใช้เพื่อสร้าง email address ของผู้ใช้โดย
# เอาชื่อมาต่อด้วยเลข 2 หลักหลังของปีเกิดและต่อด้วย @rumail.ru.ac.th แสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Name: Somsak <br>
# Age : 20 <br>
# Somsak48@rumail.ru.ac.th

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Name: Jaidee <br>
# Age : 65 <br>
# Jaidee03@rumail.ru.ac.th

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Name: Yaya <br>
# Age : 71 <br>
# Yaya97@rumail.ru.ac.th

# %%
name , age = input("Enter name and age:").split(",")
cal_age = 2568 - int(age)
cal_age = str(cal_age)
create_email = name + cal_age[-2:] + "@rumail.ru.ac.th"
print("Name:",name)
print("Age:",age)
print(create_email)
# Out:
# Name: Yaya
# Age: 71
# Yaya97@rumail.ru.ac.th
